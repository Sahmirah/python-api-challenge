# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 612

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL

url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url+"appid="+weather_api_key+"&q="+city+"&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kaitangata
# Processing Record 2 of Set 1 | port alfred
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | qandala
# Processing Record 5 of Set 1 | casablanca
# Processing Record 6 of Set 1 | port elizabeth
# Processing Record 7 of Set 1 | katsuura
# Processing Record 8 of Set 1 | dikson
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | panguipulli
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | mahebourg
# Processing Record 14 of Set 1 | conway
# Processing Record 15 of Set 1 | kruisfontein
# Processing Record 16 of Set 1 | bichura
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | longyearbyen
# Processing Record 19 of Set 1 | san benito abad
# Processing Record 20 of Set 1 | hirara
# Processing Record 21 of Set 1 | toledo
# Processing Record 22 of Set 1 | la palma
# Processing Record 23 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 1 | malakal
# Processing Record 26 of Set 1 | kodiak
# Processing Record 27 of Set 1 | tazovskiy
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | san patricio
# Processing Record 30 of Set 1 | cherskiy
# Processing Record 31 of Set 1 | mayo
# Processing Record 32 of Set 1 | sakaiminato
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | daru
# Processing Record 35 of Set 1 | mukhanovo
# City not found. Skipping...
# Processing Record 36 of Set 1 | atuona
# Processing Record 37 of Set 1 | clyde river
# Processing Record 38 of Set 1 | saint-philippe
# Processing Record 39 of Set 1 | fairbanks
# Processing Record 40 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 41 of Set 1 | maniitsoq
# Processing Record 42 of Set 1 | barrow
# Processing Record 43 of Set 1 | takaka
# Processing Record 44 of Set 1 | hermanus
# Processing Record 45 of Set 1 | sheregesh
# Processing Record 46 of Set 1 | bubaque
# Processing Record 47 of Set 1 | eirunepe
# Processing Record 48 of Set 1 | sao joao da barra
# Processing Record 49 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 1 | harper
# Processing Record 0 of Set 2 | bolshiye kaybitsy
# City not found. Skipping...
# Processing Record 1 of Set 2 | kaeo
# Processing Record 2 of Set 2 | palmer
# Processing Record 3 of Set 2 | sirajganj
# Processing Record 4 of Set 2 | morehead
# Processing Record 5 of Set 2 | khatanga
# Processing Record 6 of Set 2 | qaanaaq
# Processing Record 7 of Set 2 | amahai
# Processing Record 8 of Set 2 | port blair
# Processing Record 9 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 2 | paamiut
# Processing Record 11 of Set 2 | victoria
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | severodvinsk
# Processing Record 14 of Set 2 | hambantota
# Processing Record 15 of Set 2 | bilma
# Processing Record 16 of Set 2 | new norfolk
# Processing Record 17 of Set 2 | serenje
# Processing Record 18 of Set 2 | kapaa
# Processing Record 19 of Set 2 | nizwa
# Processing Record 20 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 2 | albany
# Processing Record 22 of Set 2 | hunza
# City not found. Skipping...
# Processing Record 23 of Set 2 | samarai
# Processing Record 24 of Set 2 | puerto ayora
# Processing Record 25 of Set 2 | guerrero negro
# Processing Record 26 of Set 2 | vostok
# Processing Record 27 of Set 2 | chaoyang
# Processing Record 28 of Set 2 | margate
# Processing Record 29 of Set 2 | hilo
# Processing Record 30 of Set 2 | grand forks
# Processing Record 31 of Set 2 | novoilinsk
# Processing Record 32 of Set 2 | sorland
# Processing Record 33 of Set 2 | nanakuli
# Processing Record 34 of Set 2 | paramonga
# Processing Record 35 of Set 2 | halalo
# City not found. Skipping...
# Processing Record
of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 19 of Set 4 | beaverlodge
# Processing Record 20 of Set 4 | mount gambier
# Processing Record 21 of Set 4 | oussouye
# Processing Record 22 of Set 4 | ondjiva
# Processing Record 23 of Set 4 | senj
# Processing Record 24 of Set 4 | yar-sale
# Processing Record 25 of Set 4 | kargasok
# Processing Record 26 of Set 4 | srednekolymsk
# Processing Record 27 of Set 4 | burica
# City not found. Skipping...
# Processing Record 28 of Set 4 | rivadavia
# Processing Record 29 of Set 4 | zhanaozen
# Processing Record 30 of Set 4 | vao
# Processing Record 31 of Set 4 | north bend
# Processing Record 32 of Set 4 | savannah bight
# Processing Record 33 of Set 4 | chissamba
# Processing Record 34 of Set 4 | pevek
# Processing Record 35 of Set 4 | suntar
# Processing Record 36 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 37 of Set 4 | jamestown
# Processing Record 38 of Set 4 | launceston
# Processing Record 39 of Set 4 | zhezkazgan
# Processing Record 40 of Set 4 | drumheller
# Processing Record 41 of Set 4 | xichang
# Processing Record 42 of Set 4 | bethel
# Processing Record 43 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 4 | boende
# Processing Record 45 of Set 4 | the valley
# Processing Record 46 of Set 4 | mar del plata
# Processing Record 47 of Set 4 | coahuayana
# Processing Record 48 of Set 4 | santa luzia
# Processing Record 49 of Set 4 | beipiao
# Processing Record 0 of Set 5 | gamba
# Processing Record 1 of Set 5 | hami
# Processing Record 2 of Set 5 | maridi
# Processing Record 3 of Set 5 | robertsport
# Processing Record 4 of Set 5 | kieta
# Processing Record 5 of Set 5 | nikolskoye
# Processing Record 6 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 5 | tucuman
# Processing Record 8 of Set 5 | yellowknife
# Processing Record 9 of Set 5 | zyryanovsk
# Processing Record 10 of Set 5 | saint george
# Processing Record 11 of Set 5 | inuvik
# Processing Record 12 of Set 5 | sept-iles
# Processing Record 13 of Set 5 | narsaq
# Processing Record 14 of Set 5 | pisco
# Processing Record 15 of Set 5 | hyeres
# Processing Record 16 of Set 5 | mecca
# Processing Record 17 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 5 | faanui
# Processing Record 19 of Set 5 | ahuimanu
# Processing Record 20 of Set 5 | boden
# Processing Record 21 of Set 5 | kibre mengist
# Processing Record 22 of Set 5 | klaksvik
# Processing Record 23 of Set 5 | georgetown
# Processing Record 24 of Set 5 | anadyr
# Processing Record 25 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 5 | half moon bay
# Processing Record 27 of Set 5 | katunino
# Processing Record 28 of Set 5 | muroto
# Processing Record 29 of Set 5 | haimen
# Processing Record 30 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 5 | misratah
# Processing Record 32 of Set 5 | leningradskiy
# Processing Record 33 of Set 5 | omaruru
# Processing Record 34 of Set 5 | poronaysk
# Processing Record 35 of Set 5 | lebu
# Processing Record 36 of Set 5 | gualaco
# Processing Record 37 of Set 5 | skelleftea
# Processing Record 38 of Set 5 | urumqi
# Processing Record 39 of Set 5 | dawei
# Processing Record 40 of Set 5 | capinzal
# Processing Record 41 of Set 5 | oriximina
# Processing Record 42 of Set 5 | prince george
# Processing Record 43 of Set 5 | great falls
# Processing Record 44 of Set 5 | banda aceh
# Processing Record 45 of Set 5 | ramon castilla
# Processing Record 46 of Set 5 | thompson
# Processing Record 47 of Set 5 | catemaco
# Processing Record 48 of Set 5 | aloleng
# Processing Record 49 of Set 5 | gragnano
# Processing Record 0 of Set 6 | sao tome
# Processing Record 1 of Set 6 | tangi
# Processing Record 2 of Set 6 | saint-augustin
# Processing Record 3 of Set 6 | iwamizawa
# Processing Record 4 of Set 6 | salinopolis
# Processing Record 5 of Set 6 | fortuna
# Processing Record 6 of Set 6 | itarema
# Processing Record 7 of Set 6 | carutapera
# Processing Record 8 of Set 6 | geraldton
# Processing Record 9 of Set 6 | karia
# Processing Record 10 of Set 6 | dong hoi
# Processing Record 11 of Set 6 | cheremnoye
# Processing Record 12 of Set 6 | ust-tarka
# Processing Record 13 of Set 6 | esperance
# Processing Record 14 of Set 6 | galle
# Processing Record 15 of Set 6 | college
# Processing Record 16 of Set 6 | faya
# Processing Record 17 of Set 6 | batagay-alyta
# Processing Record 18 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 19 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 6 | alma
# Processing Record 21 of Set 6 | nebbi
# Processing Record 22 of Set 6 | silopi
# Processing Record 23 of Set 6 | rockwall
# Processing Record 24 of Set 6 | saskylakh
# Processing Record 25 of Set 6 | impfondo
# Processing Record 26 of Set 6 | komsomolskiy
# Processing Record 27 of Set 6 | otradnoye
# Processing Record 28 of Set 6 | saquarema
# Processing Record 29 of Set 6 | shaunavon
# Processing Record 30 of Set 6 | santa rita
# Processing Record 31 of Set 6 | husavik
# Processing Record 32 of Set 6 | taltal
# Processing Record 33 of Set 6 | kuandian
# Processing Record 34 of Set 6 | lagoa
# Processing Record 35 of Set 6 | airai
# Processing Record 36 of Set 6 | vestmanna
# Processing Record 37 of Set 6 | tilichiki
# Processing Record 38 of Set 6 | san jose
# Processing Record 39 of Set 6 | aksarayskiy
# Processing Record 40 of Set 6 | cidreira
# Processing Record 41 of Set 6 | itoman
# Processing Record 42 of Set 6 | atar
# Processing Record 43 of Set 6 | mount isa
# Processing Record 44 of Set 6 | el sauzal
# Processing Record 45 of Set 6 | dunedin
# Processing Record 46 of Set 6 | sernur
# Processing Record 47 of Set 6 | riachao das neves
# Processing Record 48 of Set 6 | eyl
# Processing Record 49 of Set 6 | key biscayne
# Processing Record 0 of Set 7 | ostrovnoy
# Processing Record 1 of Set 7 | huanuco
# Processing Record 2 of Set 7 | dakar
# Processing Record 3 of Set 7 | castanos
# Processing Record 4 of Set 7 | santiago del estero
# Processing Record 5 of Set 7 | emerald
# Processing Record 6 of Set 7 | pokhara
# Processing Record 7 of Set 7 | kingaroy
# Processing Record 8 of Set 7 | zaozerne
# Processing Record 9 of Set 7 | radeberg
# Processing Record 10 of Set 7 | alyangula
# Processing Record 11 of Set 7 | teya
# Processing Record 12 of Set 7 | tuktoyaktuk
# Processing Record 13 of Set 7 | sao filipe
# Processing Record 14 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 15 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 7 | sola
# Processing Record 17 of Set 7 | belmonte
# Processing Record 18 of Set 7 | adre
# Processing Record 19 of Set 7 | shimoda
# Processing Record 20 of Set 7 | wajid
# Processing Record 21 of Set 7 | egvekinot
# Processing Record 22 of Set 7 | bah
# Processing Record 23 of Set 7 | lasa
# Processing Record 24 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record
# Processing Record 48 of Set 8 | cayenne
# Processing Record 49 of Set 8 | merauke
# Processing Record 0 of Set 9 | quebrangulo
# Processing Record 1 of Set 9 | san cristobal
# Processing Record 2 of Set 9 | gravdal
# Processing Record 3 of Set 9 | gravelbourg
# Processing Record 4 of Set 9 | barra do garcas
# Processing Record 5 of Set 9 | tommot
# Processing Record 6 of Set 9 | aykhal
# Processing Record 7 of Set 9 | honiara
# Processing Record 8 of Set 9 | clinton
# Processing Record 9 of Set 9 | vallenar
# Processing Record 10 of Set 9 | broome
# Processing Record 11 of Set 9 | xunchang
# Processing Record 12 of Set 9 | trat
# Processing Record 13 of Set 9 | soyo
# Processing Record 14 of Set 9 | comodoro rivadavia
# Processing Record 15 of Set 9 | bonthe
# Processing Record 16 of Set 9 | cartagena del chaira
# Processing Record 17 of Set 9 | sisimiut
# Processing Record 18 of Set 9 | ndele
# Processing Record 19 of Set 9 | rabo de peixe
# Processing Record 20 of Set 9 | road town
# Processing Record 21 of Set 9 | port lincoln
# Processing Record 22 of Set 9 | keetmanshoop
# Processing Record 23 of Set 9 | ancud
# Processing Record 24 of Set 9 | nouadhibou
# Processing Record 25 of Set 9 | springbok
# Processing Record 26 of Set 9 | kyzyl-mazhalyk
# Processing Record 27 of Set 9 | antofagasta
# Processing Record 28 of Set 9 | ahipara
# Processing Record 29 of Set 9 | praia da vitoria
# Processing Record 30 of Set 9 | sakakah
# Processing Record 31 of Set 9 | isangel
# Processing Record 32 of Set 9 | shache
# Processing Record 33 of Set 9 | ixtapa
# Processing Record 34 of Set 9 | calama
# Processing Record 35 of Set 9 | tiksi
# Processing Record 36 of Set 9 | maningrida
# Processing Record 37 of Set 9 | pingdu
# Processing Record 38 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 9 | tabarqah
# City not found. Skipping...
# Processing Record 40 of Set 9 | jawhar
# Processing Record 41 of Set 9 | jishui
# Processing Record 42 of Set 9 | ucluelet
# Processing Record 43 of Set 9 | preobrazheniye
# Processing Record 44 of Set 9 | chapais
# Processing Record 45 of Set 9 | mahajanga
# Processing Record 46 of Set 9 | mvomero
# Processing Record 47 of Set 9 | port hawkesbury
# Processing Record 48 of Set 9 | sterling
# Processing Record 49 of Set 9 | sao felix do xingu
# Processing Record 0 of Set 10 | trairi
# Processing Record 1 of Set 10 | porto novo
# Processing Record 2 of Set 10 | casa nova
# Processing Record 3 of Set 10 | lithakia
# Processing Record 4 of Set 10 | grand-santi
# Processing Record 5 of Set 10 | gilgit
# Processing Record 6 of Set 10 | ilulissat
# Processing Record 7 of Set 10 | muros
# Processing Record 8 of Set 10 | hashtgerd
# Processing Record 9 of Set 10 | wertheim
# Processing Record 10 of Set 10 | tautira
# Processing Record 11 of Set 10 | sinnamary
# Processing Record 12 of Set 10 | flagstaff
# Processing Record 13 of Set 10 | kahului
# Processing Record 14 of Set 10 | varnamo
# Processing Record 15 of Set 10 | corn island
# Processing Record 16 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 17 of Set 10 | riyadh
# Processing Record 18 of Set 10 | altay
# Processing Record 19 of Set 10 | alofi
# Processing Record 20 of Set 10 | okmulgee
# Processing Record 21 of Set 10 | manono
# Processing Record 22 of Set 10 | kismayo
# Processing Record 23 of Set 10 | mbuguni
# Processing Record 24 of Set 10 | kenora
# Processing Record 25 of Set 10 | olafsvik
# Processing Record 26 of Set 10 | bambous virieux
# Processing Record 27 of Set 10 | pangody
# Processing Record 28 of Set 10 | andenes
# Processing Record 29 of Set 10 | iqaluit
# Processing Record 30 of Set 10 | flinders
# Processing Record 31 of Set 10 | karamay
# City not found. Skipping...
# Processing Record 32 of Set 10 | bandarbeyla
# Processing Record 33 of Set 10 | camacha
# Processing Record 34 of Set 10 | foki
# Processing Record 35 of Set 10 | narasannapeta
# Processing Record 36 of Set 10 | mogadishu
# Processing Record 37 of Set 10 | bacolod
# Processing Record 38 of Set 10 | shaki
# Processing Record 39 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 10 | awjilah
# Processing Record 41 of Set 10 | ajdabiya
# Processing Record 42 of Set 10 | ambilobe
# Processing Record 43 of Set 10 | saint-pierre
# Processing Record 44 of Set 10 | tual
# Processing Record 45 of Set 10 | murray bridge
# Processing Record 46 of Set 10 | baruun-urt
# Processing Record 47 of Set 10 | luderitz
# Processing Record 48 of Set 10 | bintulu
# Processing Record 49 of Set 10 | killam
# Processing Record 0 of Set 11 | parfino
# Processing Record 1 of Set 11 | vanavara
# Processing Record 2 of Set 11 | angoche
# Processing Record 3 of Set 11 | sabang
# Processing Record 4 of Set 11 | onega
# Processing Record 5 of Set 11 | ribeira grande
# Processing Record 6 of Set 11 | ozuluama
# Processing Record 7 of Set 11 | beringovskiy
# Processing Record 8 of Set 11 | avera
# Processing Record 9 of Set 11 | burnie
# Processing Record 10 of Set 11 | nisia floresta
# Processing Record 11 of Set 11 | novobirilyussy
# Processing Record 12 of Set 11 | oktyabrskiy
# Processing Record 13 of Set 11 | japura
# Processing Record 14 of Set 11 | katangli
# Processing Record 15 of Set 11 | lorengau
# Processing Record 16 of Set 11 | akonolinga
# Processing Record 17 of Set 11 | lavrentiya
# Processing Record 18 of Set 11 | mozarlandia
# Processing Record 19 of Set 11 | venado
# Processing Record 20 of Set 11 | constitucion
# Processing Record 21 of Set 11 | pittsburg
# Processing Record 22 of Set 11 | kargat
# Processing Record 23 of Set 11 | usinsk
# Processing Record 24 of Set 11 | naliya
# Processing Record 25 of Set 11 | asau
# Processing Record 26 of Set 11 | bjerkvik
# Processing Record 27 of Set 11 | marzuq
# Processing Record 28 of Set 11 | nyurba
# Processing Record 29 of Set 11 | kayunga
# Processing Record 30 of Set 11 | camargo
# Processing Record 31 of Set 11 | bonito
# Processing Record 32 of Set 11 | carauari
# Processing Record 33 of Set 11 | alta
# Processing Record 34 of Set 11 | cueto
# Processing Record 35 of Set 11 | anloga
# Processing Record 36 of Set 11 | porto velho
# Processing Record 37 of Set 11 | colesberg
# Processing Record 38 of Set 11 | ahmadpur sial
# Processing Record 39 of Set 11 | vitim
# Processing Record 40 of Set 11 | vila franca do campo
# Processing Record 41 of Set 11 | plettenberg bay
# Processing Record 42 of Set 11 | kostivere
# Processing Record 43 of Set 11 | kirakira
# Processing Record 44 of Set 11 | caibarien
# Processing Record 45 of Set 11 | wheeling
# Processing Record 46 of Set 11 | whakatane
# Processing Record 47 of Set 11 | yumen
# Processing Record 48 of Set 11 | praya
# Processing Record 49 of Set 11 | olot
# Processing Record 0 of Set 12 | vardo
# Processing Record 1 of Set 12 | baracoa
# Processing Record 2 of Set 12 | banamba
# Processing Record 3 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 4 of Set 12 | caravelas
# Processing Record 5 of Set 12 | okhotsk
# Processing Record 6 of Set 12 | ende
# Processing Record 7 of Set 12 | kenai
# Processing Record 8 of Set 12 | sangar
# Processing Record 9 of Set 12 | beidao
# Processing Record 10 of Set 12 | carberry
# Processing Record 11 of Set 12 | buchanan
# Processing Record 12 of Set 12 | veraval
# Processing Record 13 of Set 12 | arkhangelsk
# Processing Record 14 of Set 12 | castro
# Processing Record 15 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 12 | boysun
# Processing Record 17 of Set 12 | maragogi
# Processing Record 18 of Set 12 | zelenoborsk
# Processing Record 19 of Set 12 | asfi
# Processing Record 20 of Set 12 | shambu
# Processing Record 21 of Set 12 | kargopol
# Processing Record 22 of Set 12 | nowy targ
# Processing Record 23 of Set 12 | wageningen
# Processing Record 24 of Set 12 | hovd
# Processing Record 25 of Set 12 | goderich
# Processing Record 26 of Set 12 | roma
# Processing Record 27 of Set 12 | smithers
# Processing Record 28 of Set 12 | boyolangu
# Processing Record 29 of Set 12 | meulaboh
# Processing Record 30 of Set 12 | portland
# Processing Record 31 of Set 12 | mahon
# Processing Record 32 of Set 12 | ruhengeri
# Processing Record 33 of Set 12 | quatre cocos
# Processing Record 34 of Set 12 | port macquarie
# Processing Record 35 of Set 12 | axim
# Processing Record 36 of Set 12 | pabna
# Processing Record 37 of Set 12 | alexandria
# Processing Record 38 of Set 12 | orbetello
# Processing Record 39 of Set 12 | berlevag
# Processing Record 40 of Set 12 | navoi
# Processing Record 41 of Set 12 | kakching
# Processing Record 42 of Set 12 | ponta do sol
# Processing Record 43 of Set 12 | devin
# Processing Record 44 of Set 12 | coromandel
# Processing Record 45 of Set 12 | makokou
# Processing Record 46 of Set 12 | moerai
# Processing Record 47 of Set 12 | holme
# Processing Record 48 of Set 12 | riviera beach
# Processing Record 49 of Set 12 | shangrao
# Processing Record 0 of Set 13 | kralendijk
# Processing Record 1 of Set 13 | rio gallegos
# Processing Record 2 of Set 13 | lesosibirsk
# Processing Record 3 of Set 13 | yugorsk
# Processing Record 4 of Set 13 | hervey bay
# Processing Record 5 of Set 13 | tuxpan
# Processing Record 6 of Set 13 | chojnice
# Processing Record 7 of Set 13 | winnemucca
# Processing Record 8 of Set 13 | ryotsu
# Processing Record 9 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 10 of Set 13 | nome
# Processing Record 11 of Set 13 | karymskoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          571
# Lat           571
# Lng           571
# Max Temp      571
# Humidity      571
# Cloudiness    571
# Wind Speed    571
# Country       571
# Date          571
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   kaitangata -46.2817  169.8464     20.17        76          99        3.55
# 1  port alfred -33.5906   26.8910     18.99        96           5        2.17
# 2        vaini -21.2000 -175.2000     28.09        89          75        4.63
# 3      qandala  11.4720   49.8728     22.22        74          37        2.28
# 4   casablanca  33.5928   -7.6192      7.01        66           9        1.69
#
#   Country        Date
# 0      NZ  1675220054
# 1      ZA  1675220012
# 2      TO  1675219985
# 3      SO  1675220054
# 4      MA  1675219757

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         kaitangata -46.2817  169.8464     20.17        76          99
# 1        port alfred -33.5906   26.8910     18.99        96           5
# 2              vaini -21.2000 -175.2000     28.09        89          75
# 3            qandala  11.4720   49.8728     22.22        74          37
# 4         casablanca  33.5928   -7.6192      7.01        66           9
#
#          Wind Speed Country        Date
# City_ID
# 0              3.55      NZ  1675220054
# 1              2.17      ZA  1675220012
# 2              4.63      TO  1675219985
# 3              2.28      SO  1675220054
# 4              1.69      MA  1675219757

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], 
           city_data_df["Max Temp"], 
           marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], 
           city_data_df["Humidity"], 
           marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], 
           city_data_df["Cloudiness"], 
           marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], 
           city_data_df["Wind Speed"], 
           marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed Plot")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# Listed Above

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df.Lat>= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3           qandala  11.4720   49.8728     22.22        74          37
# 4        casablanca  33.5928   -7.6192      7.01        66           9
# 6          katsuura  35.1333  140.3000     10.01        53          13
# 7            dikson  73.5069   80.5464    -24.36        93          23
# 13           conway  35.0887  -92.4421     -2.01        96         100
#
#          Wind Speed Country        Date
# City_ID
# 3              2.28      SO  1675220054
# 4              1.69      MA  1675219757
# 6             10.70      JP  1675219506
# 7              3.69      RU  1675219979
# 13             3.60      US  1675220056

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df.Lat< 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            kaitangata -46.2817  169.8464     20.17        76          99
# 1           port alfred -33.5906   26.8910     18.99        96           5
# 2                 vaini -21.2000 -175.2000     28.09        89          75
# 5        port elizabeth -33.9180   25.5701     19.62        97           0
# 8               rikitea -23.1203 -134.9692     26.23        69           4
#
#          Wind Speed Country        Date
# City_ID
# 0              3.55      NZ  1675220054
# 1              2.17      ZA  1675220012
# 2              4.63      TO  1675219985
# 5              2.57      ZA  1675219986
# 8              6.32      PF  1675220055

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

x_lat = northern_hemi_df["Lat"]
y_temp = northern_hemi_df["Max Temp"]

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_lat,y_temp)
regress = x_lat*slope+intercept
line = "y= "+str(round(slope,2)) + "x +"+str(round(intercept,2))

northern_hemi_df.plot(kind="scatter",x='Lat',y='Max Temp', figsize=(6,3))
plt.plot(x_lat,regress,"r-")
plt.annotate(line, (5, -20), fontsize=12, color='red')
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.show()
print(f'The r-value is: {rvalue**2}')
# Out:
# The r-value is: 0.7240899003324639

# %%
# Linear regression on Southern Hemisphere
x_lat = southern_hemi_df["Lat"]
y_temp = southern_hemi_df["Max Temp"]

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_lat,y_temp)
regress = x_lat*slope+intercept
line = "y= "+str(round(slope,2)) + "x +"+str(round(intercept,2))

southern_hemi_df.plot(kind="scatter",x='Lat',y='Max Temp', figsize=(6,3))
plt.plot(x_lat,regress,"r-")
plt.annotate(line, (-35,11), fontsize=12, color='red')
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.show()
print(f'The r-value is: {rvalue**2}')
# Out:
# The r-value is: 0.23346615412378693

# %% [markdown]
# **Discussion about the linear relationship:** Based on the two graphs, the closer the latitude is to 0 the hotter the city. Also, the less the latitude, the colder the city.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_lat = northern_hemi_df["Lat"]
y_humi = northern_hemi_df["Humidity"]

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_lat,y_humi)
regress = x_lat*slope+intercept
line = "y= "+str(round(slope,2)) + "x +"+str(round(intercept,2))

northern_hemi_df.plot(kind="scatter",x='Lat',y='Humidity', figsize=(6,3))
plt.plot(x_lat,regress,"r-")
plt.annotate(line, (50, 30), fontsize=12, color='red')
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.show()
print(f'The r-value is: {rvalue**2}')
# Out:
# The r-value is: 0.10799900850959195

# %%
# Southern Hemisphere
x_lat = southern_hemi_df["Lat"]
y_humi = southern_hemi_df["Humidity"]

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_lat,y_humi)
regress = x_lat*slope+intercept
line = "y= "+str(round(slope,2)) + "x +"+str(round(intercept,2))

southern_hemi_df.plot(kind="scatter",x='Lat',y='Humidity', figsize=(6,3))
plt.plot(x_lat,regress,"r-")
plt.annotate(line, (-20, 30), fontsize=12, color='red')
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.show()
print(f'The r-value is: {rvalue**2}')
# Out:
# The r-value is: 0.0996353796397617

# %% [markdown]
# **Discussion about the linear relationship:** Based on the two graps, in the southern hemisphere the humdity tends to be high regardless of the latitude.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_lat = northern_hemi_df["Lat"]
y_cloud = northern_hemi_df["Cloudiness"]

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_lat,y_cloud)
regress = x_lat*slope+intercept
line = "y= "+str(round(slope,2)) + "x +"+str(round(intercept,2))

northern_hemi_df.plot(kind="scatter",x='Lat',y='Cloudiness', figsize=(6,3))
plt.plot(x_lat,regress,"r-")
plt.annotate(line, (50, 30), fontsize=12, color='red')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.show()
print(f'The r-value is: {rvalue**2}')
# Out:
# The r-value is: 0.09640225457588325

# %%
# Southern Hemisphere
x_lat = southern_hemi_df["Lat"]
y_cloud = southern_hemi_df["Cloudiness"]

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_lat,y_cloud)
regress = x_lat*slope+intercept
line = "y= "+str(round(slope,2)) + "x +"+str(round(intercept,2))

southern_hemi_df.plot(kind="scatter",x='Lat',y='Cloudiness', figsize=(6,3))
plt.plot(x_lat,regress,"r-")
plt.annotate(line, (-50, 20), fontsize=12, color='red')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.show()
print(f'The r-value is: {rvalue**2}')
# Out:
# The r-value is: 0.06495689960612708

# %% [markdown]
# **Discussion about the linear relationship:** Based on the two graphs, the rate of cloudiness is not directly based on the latitude.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_lat = northern_hemi_df["Lat"]
y_wind = northern_hemi_df["Wind Speed"]

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_lat,y_wind)
regress = x_lat*slope+intercept
line = "y= "+str(round(slope,2)) + "x +"+str(round(intercept,2))

northern_hemi_df.plot(kind="scatter",x='Lat',y='Wind Speed', figsize=(6,3))
plt.plot(x_lat,regress,"r-")
plt.annotate(line, (7, 12), fontsize=12, color='red')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.show()
print(f'The r-value is: {rvalue**2}')
# Out:
# The r-value is: 0.01031423267935136

# %%
# Southern Hemisphere
x_lat = southern_hemi_df["Lat"]
y_wind = southern_hemi_df["Wind Speed"]

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_lat,y_wind)
regress = x_lat*slope+intercept
line = "y= "+str(round(slope,2)) + "x +"+str(round(intercept,2))

southern_hemi_df.plot(kind="scatter",x='Lat',y='Wind Speed', figsize=(6,3))
plt.plot(x_lat,regress,"r-")
plt.annotate(line, (-50, 10), fontsize=12, color='red')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.show()
print(f'The r-value is: {rvalue**2}')
# Out:
# The r-value is: 0.041602322309032894

# %% [markdown]
# **Discussion about the linear relationship:** Based on the two graphs, the wind speed is not dependenton on the latitude. Majority of the cities have a lower wind speed.
